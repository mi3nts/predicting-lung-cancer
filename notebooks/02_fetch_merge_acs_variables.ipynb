# %% [markdown]
# # 02 - Fetch and Merge ACS Variables for Lung Cancer Mortality
#
# This notebook fetches selected variables from the ACS Census API for years 2012-2019 and merges them with preprocessed lung cancer mortality data.
#
# ## Variables Selected (19 total):
#
# ### Standard Tables - B (14 variables):
# - Median Household Income
# - Total Population
# - Gini Index
# - Median Age
# - Hispanic Population
# - Black Population
# - White Population
# - No Vehicle (Owner)
# - No Vehicle (Renter)
# - Total Occupied Households
# - Rent Burden Count (+50%)
# - Rent Denominator
# - Total Families (Single Mother)
# - Total Families
#
# ### Summary Tables - S (5 variables):
# - Poverty Rate
# - Unemployment Rate
# - Disability Rate
# - Bachelor's Degree or Higher (%)
# - High School Degree or Higher (%)
#
# **Note:** Variable names are in Title Case format (publication-ready). Raw counts will be converted to percentages in later notebooks.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import requests
import os

# %% [markdown]
# ## 2. API Key Configuration
#
# Set your Census API key as an environment variable for security:
# ```bash
# export CENSUS_API_KEY='your_api_key_here'
# ```

# %%
API_KEY = os.getenv('CENSUS_API_KEY')

if API_KEY is None:
    API_KEY = 'your_api_key_here'
    print("Warning: Using hardcoded API key. Consider using environment variable for security.")
else:
    print("API key loaded from environment variable")
# Out:
# Warning: Using hardcoded API key. Consider using environment variable for security.

# %% [markdown]
# ## 3. Function Definitions
#
# Two functions to handle different ACS table types: B (standard) and S (summary).

# %% [markdown]
# ### 3.1 Function for Standard Tables (B)

# %%
def fetch_and_merge_acs_variable(variable_code, variable_name, year, api_key):
    preprocessed_path = f'../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_{year}.csv'
    output_path = f'../data/processed/acs_individual_variables/dataset_with_{variable_name}_{year}.csv'

    print(f"Loading preprocessed data for {year}...")
    preprocessed_df = pd.read_csv(preprocessed_path)

    print(f"Fetching {variable_name} ({variable_code}) from Census API for {year}...")
    acs_endpoint = f'https://api.census.gov/data/{year}/acs/acs5'
    params = {
        'get': variable_code,
        'for': 'county:*',
        'in': 'state:*',
        'key': api_key
    }

    response = requests.get(acs_endpoint, params=params)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch {variable_name}. Status code: {response.status_code}")

    acs_data = response.json()
    acs_df = pd.DataFrame(columns=acs_data[0], data=acs_data[1:])
    acs_df = acs_df.rename(columns={
        variable_code: variable_name,
        'state': 'State_FIPS',
        'county': 'County_FIPS'
    })

    preprocessed_df['State_FIPS'] = preprocessed_df['State_FIPS'].astype(str).str.zfill(2)
    preprocessed_df['County_FIPS'] = preprocessed_df['County_FIPS'].astype(str).str.zfill(3)
    acs_df['State_FIPS'] = acs_df['State_FIPS'].str.zfill(2)
    acs_df['County_FIPS'] = acs_df['County_FIPS'].str.zfill(3)

    acs_df[variable_name] = pd.to_numeric(acs_df[variable_name], errors='coerce')

    final_df = pd.merge(
        preprocessed_df,
        acs_df[['State_FIPS', 'County_FIPS', variable_name]],
        on=['State_FIPS', 'County_FIPS'],
        how='left'
    )

    if 'lung_cancer_mortality_rate' not in final_df.columns:
        raise ValueError("'lung_cancer_mortality_rate' column is missing in the final merged dataset.")

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    final_df.to_csv(output_path, index=False)
    print(f"  Saved: {output_path}")

    return final_df

# %% [markdown]
# ### 3.2 Function for Summary Tables (S)

# %%
def fetch_and_merge_acs_variable_summary(variable_code, variable_name, year, api_key):
    preprocessed_path = f'../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_{year}.csv'
    output_path = f'../data/processed/acs_individual_variables/dataset_with_{variable_name}_{year}.csv'

    print(f"Loading preprocessed data for {year}...")
    preprocessed_df = pd.read_csv(preprocessed_path)

    print(f"Fetching {variable_name} ({variable_code}) from Census API for {year}...")
    acs_endpoint = f'https://api.census.gov/data/{year}/acs/acs5/subject'
    params = {
        'get': variable_code,
        'for': 'county:*',
        'in': 'state:*',
        'key': api_key
    }

    response = requests.get(acs_endpoint, params=params)
    if response.status_code != 200:
        raise Exception(f"Failed to fetch {variable_name}. Status code: {response.status_code}")

    acs_data = response.json()
    acs_df = pd.DataFrame(columns=acs_data[0], data=acs_data[1:])
    acs_df = acs_df.rename(columns={
        variable_code: variable_name,
        'state': 'State_FIPS',
        'county': 'County_FIPS'
    })

    preprocessed_df['State_FIPS'] = preprocessed_df['State_FIPS'].astype(str).str.zfill(2)
    preprocessed_df['County_FIPS'] = preprocessed_df['County_FIPS'].astype(str).str.zfill(3)
    acs_df['State_FIPS'] = acs_df['State_FIPS'].str.zfill(2)
    acs_df['County_FIPS'] = acs_df['County_FIPS'].str.zfill(3)

    acs_df[variable_name] = pd.to_numeric(acs_df[variable_name], errors='coerce')

    final_df = pd.merge(
        preprocessed_df,
        acs_df[['State_FIPS', 'County_FIPS', variable_name]],
        on=['State_FIPS', 'County_FIPS'],
        how='left'
    )

    if 'lung_cancer_mortality_rate' not in final_df.columns:
        raise ValueError("'lung_cancer_mortality_rate' column is missing in the final merged dataset.")

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    final_df.to_csv(output_path, index=False)
    print(f"  Saved: {output_path}")

    return final_df

# %% [markdown]
# ## 4. Fetch Standard Variables (B Tables)
#
# Demographic and economic variables for all counties, 2012-2019.

# %%
standard_variables = [
    {'code': 'B19013_001E', 'name': 'Median Household Income'},
    {'code': 'B01003_001E', 'name': 'Total Population'},
    {'code': 'B19083_001E', 'name': 'Gini Index'},
    {'code': 'B01002_001E', 'name': 'Median Age'},
    {'code': 'B03003_003E', 'name': 'Hispanic Population'},
    {'code': 'B02001_003E', 'name': 'Black Population'},
    {'code': 'B02001_002E', 'name': 'White Population'},
    {'code': 'B25044_003E', 'name': 'No Vehicle (Owner)'},
    {'code': 'B25044_010E', 'name': 'No Vehicle (Renter)'},
    {'code': 'B25044_001E', 'name': 'Total Occupied Households'},
    {'code': 'B25070_010E', 'name': 'Rent Burden Count (+50%)'},
    {'code': 'B25070_001E', 'name': 'Rent Denominator'},
    {'code': 'B11003_016E', 'name': 'Total Families (Single Mother)'},
    {'code': 'B11003_001E', 'name': 'Total Families'}
]

for year in range(2012, 2020):
    print(f"\n--- Year {year} ---")
    for var in standard_variables:
        fetch_and_merge_acs_variable(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key=API_KEY
        )

print("\nAll standard variables fetched successfully!")
# Out:
# --- Year 2012 ---
# Loading preprocessed data for 2012...
# Fetching Median Household Income (B19013_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2012.csv
# Loading preprocessed data for 2012...
# Fetching Total Population (B01003_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2012.csv
# Loading preprocessed data for 2012...
# Fetching Gini Index (B19083_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2012.csv
# Loading preprocessed data for 2012...
# Fetching Median Age (B01002_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2012.csv
# Loading preprocessed data for 2012...
# Fetching Hispanic Population (B03003_003E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2012.csv
# Loading preprocessed data for 2012...
# Fetching Black Population (B02001_003E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2012.csv
# Loading preprocessed data for 2012...
# Fetching White Population (B02001_002E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2012.csv
# Loading preprocessed data for 2012...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2012.csv
# Loading preprocessed data for 2012...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2012.csv
# Loading preprocessed data for 2012...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2012.csv
# Loading preprocessed data for 2012...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2012.csv
# Loading preprocessed data for 2012...
# Fetching Rent Denominator (B25070_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2012.csv
# Loading preprocessed data for 2012...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2012.csv
# Loading preprocessed data for 2012...
# Fetching Total Families (B11003_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2012.csv
#
# --- Year 2013 ---
# Loading preprocessed data for 2013...
# Fetching Median Household Income (B19013_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2013.csv
# Loading preprocessed data for 2013...
# Fetching Total Population (B01003_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2013.csv
# Loading preprocessed data for 2013...
# Fetching Gini Index (B19083_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2013.csv
# Loading preprocessed data for 2013...
# Fetching Median Age (B01002_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2013.csv
# Loading preprocessed data for 2013...
# Fetching Hispanic Population (B03003_003E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2013.csv
# Loading preprocessed data for 2013...
# Fetching Black Population (B02001_003E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2013.csv
# Loading preprocessed data for 2013...
# Fetching White Population (B02001_002E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2013.csv
# Loading preprocessed data for 2013...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2013.csv
# Loading preprocessed data for 2013...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2013.csv
# Loading preprocessed data for 2013...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2013.csv
# Loading preprocessed data for 2013...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2013.csv
# Loading preprocessed data for 2013...
# Fetching Rent Denominator (B25070_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2013.csv
# Loading preprocessed data for 2013...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2013.csv
# Loading preprocessed data for 2013...
# Fetching Total Families (B11003_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2013.csv
#
# --- Year 2014 ---
# Loading preprocessed data for 2014...
# Fetching Median Household Income (B19013_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2014.csv
# Loading preprocessed data for 2014...
# Fetching Total Population (B01003_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2014.csv
# Loading preprocessed data for 2014...
# Fetching Gini Index (B19083_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2014.csv
# Loading preprocessed data for 2014...
# Fetching Median Age (B01002_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2014.csv
# Loading preprocessed data for 2014...
# Fetching Hispanic Population (B03003_003E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2014.csv
# Loading preprocessed data for 2014...
# Fetching Black Population (B02001_003E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2014.csv
# Loading preprocessed data for 2014...
# Fetching White Population (B02001_002E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2014.csv
# Loading preprocessed data for 2014...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2014.csv
# Loading preprocessed data for 2014...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2014.csv
# Loading preprocessed data for 2014...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2014.csv
# Loading preprocessed data for 2014...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2014.csv
# Loading preprocessed data for 2014...
# Fetching Rent Denominator (B25070_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2014.csv
# Loading preprocessed data for 2014...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2014.csv
# Loading preprocessed data for 2014...
# Fetching Total Families (B11003_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2014.csv
#
# --- Year 2015 ---
# Loading preprocessed data for 2015...
# Fetching Median Household Income (B19013_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2015.csv
# Loading preprocessed data for 2015...
# Fetching Total Population (B01003_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2015.csv
# Loading preprocessed data for 2015...
# Fetching Gini Index (B19083_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2015.csv
# Loading preprocessed data for 2015...
# Fetching Median Age (B01002_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2015.csv
# Loading preprocessed data for 2015...
# Fetching Hispanic Population (B03003_003E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2015.csv
# Loading preprocessed data for 2015...
# Fetching Black Population (B02001_003E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2015.csv
# Loading preprocessed data for 2015...
# Fetching White Population (B02001_002E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2015.csv
# Loading preprocessed data for 2015...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2015.csv
# Loading preprocessed data for 2015...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2015.csv
# Loading preprocessed data for 2015...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2015.csv
# Loading preprocessed data for 2015...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2015.csv
# Loading preprocessed data for 2015...
# Fetching Rent Denominator (B25070_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2015.csv
# Loading preprocessed data for 2015...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2015.csv
# Loading preprocessed data for 2015...
# Fetching Total Families (B11003_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2015.csv
#
# --- Year 2016 ---
# Loading preprocessed data for 2016...
# Fetching Median Household Income (B19013_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2016.csv
# Loading preprocessed data for 2016...
# Fetching Total Population (B01003_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2016.csv
# Loading preprocessed data for 2016...
# Fetching Gini Index (B19083_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2016.csv
# Loading preprocessed data for 2016...
# Fetching Median Age (B01002_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2016.csv
# Loading preprocessed data for 2016...
# Fetching Hispanic Population (B03003_003E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2016.csv
# Loading preprocessed data for 2016...
# Fetching Black Population (B02001_003E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2016.csv
# Loading preprocessed data for 2016...
# Fetching White Population (B02001_002E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2016.csv
# Loading preprocessed data for 2016...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2016.csv
# Loading preprocessed data for 2016...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2016.csv
# Loading preprocessed data for 2016...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2016.csv
# Loading preprocessed data for 2016...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2016.csv
# Loading preprocessed data for 2016...
# Fetching Rent Denominator (B25070_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2016.csv
# Loading preprocessed data for 2016...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2016.csv
# Loading preprocessed data for 2016...
# Fetching Total Families (B11003_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2016.csv
#
# --- Year 2017 ---
# Loading preprocessed data for 2017...
# Fetching Median Household Income (B19013_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2017.csv
# Loading preprocessed data for 2017...
# Fetching Total Population (B01003_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2017.csv
# Loading preprocessed data for 2017...
# Fetching Gini Index (B19083_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2017.csv
# Loading preprocessed data for 2017...
# Fetching Median Age (B01002_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2017.csv
# Loading preprocessed data for 2017...
# Fetching Hispanic Population (B03003_003E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2017.csv
# Loading preprocessed data for 2017...
# Fetching Black Population (B02001_003E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2017.csv
# Loading preprocessed data for 2017...
# Fetching White Population (B02001_002E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2017.csv
# Loading preprocessed data for 2017...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2017.csv
# Loading preprocessed data for 2017...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2017.csv
# Loading preprocessed data for 2017...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2017.csv
# Loading preprocessed data for 2017...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2017.csv
# Loading preprocessed data for 2017...
# Fetching Rent Denominator (B25070_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2017.csv
# Loading preprocessed data for 2017...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2017.csv
# Loading preprocessed data for 2017...
# Fetching Total Families (B11003_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2017.csv
#
# --- Year 2018 ---
# Loading preprocessed data for 2018...
# Fetching Median Household Income (B19013_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2018.csv
# Loading preprocessed data for 2018...
# Fetching Total Population (B01003_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2018.csv
# Loading preprocessed data for 2018...
# Fetching Gini Index (B19083_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2018.csv
# Loading preprocessed data for 2018...
# Fetching Median Age (B01002_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2018.csv
# Loading preprocessed data for 2018...
# Fetching Hispanic Population (B03003_003E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2018.csv
# Loading preprocessed data for 2018...
# Fetching Black Population (B02001_003E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2018.csv
# Loading preprocessed data for 2018...
# Fetching White Population (B02001_002E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2018.csv
# Loading preprocessed data for 2018...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2018.csv
# Loading preprocessed data for 2018...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2018.csv
# Loading preprocessed data for 2018...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2018.csv
# Loading preprocessed data for 2018...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2018.csv
# Loading preprocessed data for 2018...
# Fetching Rent Denominator (B25070_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2018.csv
# Loading preprocessed data for 2018...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2018.csv
# Loading preprocessed data for 2018...
# Fetching Total Families (B11003_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2018.csv
#
# --- Year 2019 ---
# Loading preprocessed data for 2019...
# Fetching Median Household Income (B19013_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Household Income_2019.csv
# Loading preprocessed data for 2019...
# Fetching Total Population (B01003_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Population_2019.csv
# Loading preprocessed data for 2019...
# Fetching Gini Index (B19083_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Gini Index_2019.csv
# Loading preprocessed data for 2019...
# Fetching Median Age (B01002_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Median Age_2019.csv
# Loading preprocessed data for 2019...
# Fetching Hispanic Population (B03003_003E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Hispanic Population_2019.csv
# Loading preprocessed data for 2019...
# Fetching Black Population (B02001_003E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Black Population_2019.csv
# Loading preprocessed data for 2019...
# Fetching White Population (B02001_002E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_White Population_2019.csv
# Loading preprocessed data for 2019...
# Fetching No Vehicle (Owner) (B25044_003E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Owner)_2019.csv
# Loading preprocessed data for 2019...
# Fetching No Vehicle (Renter) (B25044_010E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_No Vehicle (Renter)_2019.csv
# Loading preprocessed data for 2019...
# Fetching Total Occupied Households (B25044_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Occupied Households_2019.csv
# Loading preprocessed data for 2019...
# Fetching Rent Burden Count (+50%) (B25070_010E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Burden Count (+50%)_2019.csv
# Loading preprocessed data for 2019...
# Fetching Rent Denominator (B25070_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Rent Denominator_2019.csv
# Loading preprocessed data for 2019...
# Fetching Total Families (Single Mother) (B11003_016E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families (Single Mother)_2019.csv
# Loading preprocessed data for 2019...
# Fetching Total Families (B11003_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Total Families_2019.csv
#
# All standard variables fetched successfully!

# %% [markdown]
# ## 5. Fetch Summary Table Variables (S Tables)
#
# Health, social, and education variables.

# %%
summary_variables = [
    {'code': 'S1701_C03_001E', 'name': 'Poverty Rate'},
    {'code': 'S2301_C04_001E', 'name': 'Unemployment Rate'},
    {'code': 'S1810_C03_001E', 'name': 'Disability Rate'},
    {'code': 'S1501_C02_015E', 'name': "Bachelor's Degree or Higher (%)"},
    {'code': 'S1501_C02_014E', 'name': 'High School Degree or Higher (%)'}
]

print("=" * 60)
print("FETCHING SUMMARY TABLE VARIABLES (S Tables)")
print("=" * 60)

for year in range(2012, 2020):
    print(f"\n--- Year {year} ---")
    for var in summary_variables:
        fetch_and_merge_acs_variable_summary(
            variable_code=var['code'],
            variable_name=var['name'],
            year=year,
            api_key=API_KEY
        )

print("\nAll summary table variables fetched successfully!")
# Out:
# ============================================================
# FETCHING SUMMARY TABLE VARIABLES (S Tables)
# ============================================================
#
# --- Year 2012 ---
# Loading preprocessed data for 2012...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2012.csv
# Loading preprocessed data for 2012...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2012.csv
# Loading preprocessed data for 2012...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2012.csv
# Loading preprocessed data for 2012...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2012.csv
# Loading preprocessed data for 2012...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2012...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2012.csv
#
# --- Year 2013 ---
# Loading preprocessed data for 2013...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2013.csv
# Loading preprocessed data for 2013...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2013.csv
# Loading preprocessed data for 2013...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2013.csv
# Loading preprocessed data for 2013...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2013.csv
# Loading preprocessed data for 2013...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2013...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2013.csv
#
# --- Year 2014 ---
# Loading preprocessed data for 2014...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2014.csv
# Loading preprocessed data for 2014...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2014.csv
# Loading preprocessed data for 2014...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2014.csv
# Loading preprocessed data for 2014...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2014.csv
# Loading preprocessed data for 2014...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2014...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2014.csv
#
# --- Year 2015 ---
# Loading preprocessed data for 2015...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2015.csv
# Loading preprocessed data for 2015...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2015.csv
# Loading preprocessed data for 2015...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2015.csv
# Loading preprocessed data for 2015...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2015.csv
# Loading preprocessed data for 2015...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2015...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2015.csv
#
# --- Year 2016 ---
# Loading preprocessed data for 2016...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2016.csv
# Loading preprocessed data for 2016...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2016.csv
# Loading preprocessed data for 2016...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2016.csv
# Loading preprocessed data for 2016...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2016.csv
# Loading preprocessed data for 2016...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2016...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2016.csv
#
# --- Year 2017 ---
# Loading preprocessed data for 2017...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2017.csv
# Loading preprocessed data for 2017...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2017.csv
# Loading preprocessed data for 2017...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2017.csv
# Loading preprocessed data for 2017...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2017.csv
# Loading preprocessed data for 2017...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2017...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2017.csv
#
# --- Year 2018 ---
# Loading preprocessed data for 2018...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2018.csv
# Loading preprocessed data for 2018...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2018.csv
# Loading preprocessed data for 2018...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2018.csv
# Loading preprocessed data for 2018...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2018.csv
# Loading preprocessed data for 2018...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2018...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2018.csv
#
# --- Year 2019 ---
# Loading preprocessed data for 2019...
# Fetching Poverty Rate (S1701_C03_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Poverty Rate_2019.csv
# Loading preprocessed data for 2019...
# Fetching Unemployment Rate (S2301_C04_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Unemployment Rate_2019.csv
# Loading preprocessed data for 2019...
# Fetching Disability Rate (S1810_C03_001E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Disability Rate_2019.csv
# Loading preprocessed data for 2019...
# Fetching Bachelor's Degree or Higher (%) (S1501_C02_015E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_Bachelor's Degree or Higher (%)_2019.csv
# Loading preprocessed data for 2019...
# Fetching High School Degree or Higher (%) (S1501_C02_014E) from Census API for 2019...
#   Saved: ../data/processed/acs_individual_variables/dataset_with_High School Degree or Higher (%)_2019.csv
#
# All summary table variables fetched successfully!

# %% [markdown]
# ## 6. Summary
#
# All ACS variables have been fetched and merged with lung cancer mortality data for years 2012-2019.
#
# **Output location:** `../data/processed/acs_individual_variables/`
#
# **Total files created:** 19 variables × 8 years = 152 CSV files
#
# Each file contains:
# - County and State information
# - State_FIPS and County_FIPS codes
# - Fips (full 5-digit FIPS code)
# - `lung_cancer_mortality_rate` (target variable)
# - The corresponding ACS variable (in Title Case)
#
# **Next step:** Proceed to notebook 03 to combine all features into a single dataset for each year.

# %%
output_dir = '../data/processed/acs_individual_variables/'
if os.path.exists(output_dir):
    files = [f for f in os.listdir(output_dir) if f.endswith('.csv')]
    print(f"Total files created: {len(files)}")
    print(f"\nSample files:")
    for f in sorted(files)[:5]:
        print(f"  {f}")
# Out:
# Total files created: 152
#
# Sample files:
#   dataset_with_Bachelor's Degree or Higher (%)_2012.csv
#   dataset_with_Bachelor's Degree or Higher (%)_2013.csv
#   dataset_with_Bachelor's Degree or Higher (%)_2014.csv
#   dataset_with_Bachelor's Degree or Higher (%)_2015.csv
#   dataset_with_Bachelor's Degree or Higher (%)_2016.csv
