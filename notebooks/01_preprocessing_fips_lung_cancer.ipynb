# %% [markdown]
# # 01 - Preprocess FIPS Codes for Lung Cancer Mortality Data
#
# This notebook merges the lung cancer mortality data with FIPS codes to enable joining with other datasets (ACS, weather, livestock).
#
# The location names in IHME data are in the format "County Name (State)", which we parse to extract County and State, then merge with the FIPS lookup table.

# %%
import pandas as pd
import os

# %%
def preprocess_fips_lung_cancer(year):
    """
    Preprocesses and merges FIPS data with lung cancer mortality data for a given year.
    
    Parameters:
    year (int): The year of the lung cancer mortality data (e.g., 2012).
    
    Returns:
    pd.DataFrame: Preprocessed DataFrame with lung cancer mortality and FIPS codes.
    """
    fips_path = '../data/state_fips.csv'
    lung_cancer_path = f'../data/processed/lung_cancer_single_year/lung_cancer_mortality_{year}.csv'

    fips_df = pd.read_csv(fips_path, dtype={'fips': str})
    fips_df['fips'] = fips_df['fips'].str.zfill(5)
    fips_df['State_FIPS'] = fips_df['fips'].str[:2]
    fips_df['County_FIPS'] = fips_df['fips'].str[2:]
    fips_df['state_full'] = fips_df['state'].map({
        'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas',
        'CA': 'California', 'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware',
        'FL': 'Florida', 'GA': 'Georgia', 'HI': 'Hawaii', 'ID': 'Idaho',
        'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa', 'KS': 'Kansas',
        'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland',
        'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi',
        'MO': 'Missouri', 'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada',
        'NH': 'New Hampshire', 'NJ': 'New Jersey', 'NM': 'New Mexico', 'NY': 'New York',
        'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio', 'OK': 'Oklahoma',
        'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina',
        'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah',
        'VT': 'Vermont', 'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia',
        'WI': 'Wisconsin', 'WY': 'Wyoming'
    })

    lung_cancer_df = pd.read_csv(lung_cancer_path)

    lung_cancer_df[['County', 'State']] = lung_cancer_df['location_name'].str.extract(r'^(.*) \((.*)\)$')

    lung_cancer_df = lung_cancer_df[['County', 'State', 'lung_cancer_mortality_rate', 'year']].copy()
    lung_cancer_df['County'] = lung_cancer_df['County'].str.strip()
    lung_cancer_df['State'] = lung_cancer_df['State'].str.strip()

    merged_df = pd.merge(
        lung_cancer_df,
        fips_df[['State_FIPS', 'County_FIPS', 'name', 'state_full', 'fips']],
        left_on=['State', 'County'],
        right_on=['state_full', 'name'],
        how='left'
    )

    merged_df = merged_df.rename(columns={'fips': 'Fips'})

    return merged_df.drop(columns=['name', 'state_full'])

# %% [markdown]
# ## Test with a Single Year

# %%
# Test with 2012
df_test = preprocess_fips_lung_cancer(2012)
print(f"Shape: {df_test.shape}")
print(f"Columns: {df_test.columns.tolist()}")
df_test.head()
# Out:
# Shape: (3127, 7)
# Columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#            County    State  lung_cancer_mortality_rate  year State_FIPS  \
# 0  Autauga County  Alabama                    0.000756  2012         01
# 1  Baldwin County  Alabama                    0.000620  2012         01
# 2  Barbour County  Alabama                    0.000790  2012         01
# 3     Bibb County  Alabama                    0.000827  2012         01
# 4   Blount County  Alabama                    0.000754  2012         01
#
#   County_FIPS   Fips
# 0         001  01001
# 1         003  01003
# 2         005  01005
# 3         007  01007
# 4         009  01009

# %%
# Check for missing FIPS codes
missing_fips = df_test[df_test['Fips'].isna()]
print(f"Rows with missing FIPS: {len(missing_fips)}")
if len(missing_fips) > 0:
    print("Sample missing rows:")
    print(missing_fips[['County', 'State']].head(10))
# Out:
# Rows with missing FIPS: 16
# Sample missing rows:
#                                           County   State
# 80                           Chugach Census Area  Alaska
# 81                      Copper River Census Area  Alaska
# 83                          Kusilvak Census Area  Alaska
# 85                             Kobuk Census Area  Alaska
# 87                  Aleutian Islands Census Area  Alaska
# 96            Skagway-Yakutat-Angoon Census Area  Alaska
# 97             Skagway-Hoonah-Angoon Census Area  Alaska
# 102  Prince of Wales-Outer Ketchikan Census Area  Alaska
# 104              Wrangell-Petersburg Census Area  Alaska
# 325                                          NaN     NaN

# %% [markdown]
# ## Process All Years (2012-2019)

# %%
# Ensure output directory exists
output_dir = '../data/processed/preprocessed_fips_lung_cancer/'
os.makedirs(output_dir, exist_ok=True)

# Process all years
for year in range(2012, 2020):
    df = preprocess_fips_lung_cancer(year)
    df.dropna(inplace=True)
    output_path = f'{output_dir}preprocessed_lung_cancer_fips_{year}.csv'
    df.to_csv(output_path, index=False)
    print(f"Year {year}: {len(df)} rows saved to {output_path}")
# Out:
# Year 2012: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2012.csv
# Year 2013: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2013.csv
# Year 2014: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2014.csv
# Year 2015: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2015.csv
# Year 2016: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2016.csv
# Year 2017: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2017.csv
# Year 2018: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2018.csv
# Year 2019: 3111 rows saved to ../data/processed/preprocessed_fips_lung_cancer/preprocessed_lung_cancer_fips_2019.csv

# %% [markdown]
# ## Verify Output Files

# %%
# List all generated files
files = sorted([f for f in os.listdir(output_dir) if f.endswith('.csv')])
print("Generated files:")
for f in files:
    filepath = os.path.join(output_dir, f)
    df = pd.read_csv(filepath)
    print(f"  {f}: {len(df)} rows, columns: {df.columns.tolist()}")
# Out:
# Generated files:
#   preprocessed_lung_cancer_fips_2012.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#   preprocessed_lung_cancer_fips_2013.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#   preprocessed_lung_cancer_fips_2014.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#   preprocessed_lung_cancer_fips_2015.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#   preprocessed_lung_cancer_fips_2016.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
#   preprocessed_lung_cancer_fips_2017.csv: 3111 rows, columns: ['County', 'State', 'lung_cancer_mortality_rate', 'year', 'State_FIPS', 'County_FIPS', 'Fips']
# ...

# %%
# Sample the final output
df_sample = pd.read_csv(f'{output_dir}preprocessed_lung_cancer_fips_2012.csv')
df_sample.head(10)
# Out:
#             County    State  lung_cancer_mortality_rate  year  State_FIPS  \
# 0   Autauga County  Alabama                    0.000756  2012           1
# 1   Baldwin County  Alabama                    0.000620  2012           1
# 2   Barbour County  Alabama                    0.000790  2012           1
# 3      Bibb County  Alabama                    0.000827  2012           1
# 4    Blount County  Alabama                    0.000754  2012           1
# 5   Bullock County  Alabama                    0.000692  2012           1
# 6    Butler County  Alabama                    0.000701  2012           1
# 7   Calhoun County  Alabama                    0.000860  2012           1
# 8  Chambers County  Alabama                    0.000789  2012           1
# 9  Cherokee County  Alabama                    0.000767  2012           1
#
#    County_FIPS  Fips
# 0            1  1001
# 1            3  1003
# 2            5  1005
# 3            7  1007
# 4            9  1009
# ...
